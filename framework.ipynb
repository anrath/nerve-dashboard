# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os

# %%
# Loads the dataset into memory. Takes ~45 seconds to load the dataset.
df = pd.read_csv('./data/Syn.csv')
# df = pd.read_csv('./data/data-primary/unbalaced_20_80_dataset.csv')
# Out:
# /tmp/ipykernel_17206/3996427861.py:2: DtypeWarning: Columns (85) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/Syn.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                Flow ID     Source IP
# 0      445444    172.16.0.5-192.168.50.4-9429-9429-6    172.16.0.5  \
# 1      113842  172.16.0.5-192.168.50.4-60224-60224-6    172.16.0.5
# 2      176377  172.16.0.5-192.168.50.4-33827-11746-6  192.168.50.4
# 3       24777   172.16.0.5-192.168.50.4-33828-1431-6    172.16.0.5
# 4       85100    172.16.0.5-192.168.50.4-5311-5311-6    172.16.0.5
#
#     Source Port  Destination IP   Destination Port   Protocol
# 0          9429    192.168.50.4               9429          6  \
# 1         60224    192.168.50.4              60224          6
# 2         11746      172.16.0.5              33827          6
# 3         33828    192.168.50.4               1431          6
# 4          5311    192.168.50.4               5311          6
#
#                     Timestamp   Flow Duration   Total Fwd Packets  ...
# 0  2018-11-03 11:36:28.607338        36063894                   7  ...  \
# ...

# %%
temp = df[['Flow ID', 'Src IP', 'Dst IP', 'Src Port', 'Dst Port', 'Protocol', 'Timestamp', 'Flow Duration', 'Tot Fwd Pkts', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt']]

# %%
temp.head()
# Out:
#                                   Flow ID          Src IP         Dst IP
# 0   172.31.69.25-18.219.193.20-80-37882-6   18.219.193.20   172.31.69.25  \
# 1      172.31.69.28-18.219.9.1-80-63287-6    172.31.69.28     18.219.9.1
# 2   172.31.69.28-52.14.136.135-80-63095-6   52.14.136.135   172.31.69.28
# 3  172.31.69.28-18.216.200.189-80-52341-6  18.216.200.189   172.31.69.28
# 4   172.31.69.28-18.218.55.126-80-57459-6    172.31.69.28  18.218.55.126
#
#    Src Port  Dst Port  Protocol               Timestamp  Flow Duration
# 0     37882        80         6  16/02/2018 11:27:29 PM           8660  \
# 1        80     63287         6  22/02/2018 12:13:52 AM           5829
# 2     63095        80         6  22/02/2018 12:14:02 AM           3396
# 3     52341        80         6  22/02/2018 12:28:04 AM           2390
# 4        80     57459         6  22/02/2018 12:19:45 AM          17362
#
#    Tot Fwd Pkts  SYN Flag Cnt  RST Flag Cnt  PSH Flag Cnt  ACK Flag Cnt
# ...
